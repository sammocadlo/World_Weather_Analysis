# %%
#create a new set of 2000 random latitudes and longitudes

#import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import time
from datetime import datetime

import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descrip = city_weather['weather'][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Decription":city_weather_descrip,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | takoradi
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | duvan
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | cernesti
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | aksu
# Processing Record 9 of Set 1 | saint anthony
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | margate
# Processing Record 12 of Set 1 | gizo
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | shingu
# Processing Record 16 of Set 1 | bubaque
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | noyabrsk
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | viedma
# Processing Record 25 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | valley city
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | pangai
# Processing Record 32 of Set 1 | kismayo
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | pangnirtung
# Processing Record 40 of Set 1 | santa pola
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | kariba
# Processing Record 43 of Set 1 | portland
# Processing Record 44 of Set 1 | pacific grove
# Processing Record 45 of Set 1 | mocuba
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | sisimiut
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | asau
# Processing Record 1 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | nhulunbuy
# Processing Record 4 of Set 2 | lorengau
# Processing Record 5 of Set 2 | korla
# Processing Record 6 of Set 2 | yeovil
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | selma
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | diu
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | asfi
# Processing Record 15 of Set 2 | haines junction
# Processing Record 16 of Set 2 | baykit
# Processing Record 17 of Set 2 | taksimo
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | mandera
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | tual
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | taoudenni
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | raudeberg
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | port hardy
# Processing Record 31 of Set 2 | marsh harbour
# Processing Record 32 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | inongo
# Processing Record 38 of Set 2 | seoul
# Processing Record 39 of Set 2 | ayan
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | daru
# Processing Record 42 of Set 2 | isangel
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | two rivers
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | mount isa
# Processing Record 49 of Set 2 | setermoen
# Processing Record 50 of Set 2 | lazaro cardenas
# Processing Record 1 of Set 3 | cam ranh
# Processing Record 2 of Set 3 | alta floresta
# Processing Record 3 of Set 3 | punta arenas
# Processing Record 4 of Set 3 | boa vista
# Processing Record 5 of Set 3 | luena
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | taltal
# Processing Record 8 of Set 3 | yulara
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | tessalit
# Processing Record 11 of Set 3 | chifeng
# Processing Record 12 of Set 3 | tucuman
# Processing Record 13 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 3 | rikitea
# Processing Record 15 of Set 3 | campbellsville
# Processing Record 16 of Set 3 | kalundborg
# Processing Record 17 of Set 3 | zlobin
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | vila velha
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | lasa
# Processing Record 23 of Set 3 | chaman
# Processing Record 24 of Set 3 | norway
# Processing Record 25 of Set 3 | qaqortoq
# Processing Record 26 of Set 3 | batagay-alyta
# Processing Record 27 of Set 3 | ca mau
# Processing Record 28 of Set 3 | zaozerne
# Processing Record 29 of Set 3 | pafos
# Processing Record 30 of Set 3 | sinazongwe
# Processing Record 31 of Set 3 | avera
# Processing Record 32 of Set 3 | butzow
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | el retorno
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | puerto madero
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | yeppoon
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | sayyan
# Processing Record 42 of Set 3 | moron
# Processing Record 43 of Set 3 | pingzhuang
# Processing Record 44 of Set 3 | bandarbeyla
# Processing Record 45 of Set 3 | cartagena
# Processing Record 46 of Set 3 | dingle
# Processing Record 47 of Set 3 | nome
# Processing Record 48 of Set 3 | tokur
# Processing Record 49 of Set 3 | ordu
# Processing Record 50 of Set 3 | lavrentiya
# Processing Record 1 of Set 4 | yerbogachen
# Processing Record 2 of Set 4 | ararat
# Processing Record 3 of Set 4 | pando
# Processing Record 4 of Set 4 | bonavista
# Processing Record 5 of Set 4 | asbestos
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | rio gallegos
# Processing Record 8 of Set 4 | tocopilla
# Processing Record 9 of Set 4 | wad rawah
# Processing Record 10 of Set 4 | nabisar
# Processing Record 11 of Set 4 | liepaja
# Processing Record 12 of Set 4 | rosetown
# Processing Record 13 of Set 4 | staryy oskol
# Processing Record 14 of Set 4 | gavle
# Processing Record 15 of Set 4 | plouzane
# Processing Record 16 of Set 4 | blagodatnoye
# Processing Record 17 of Set 4 | wilmington
# Processing Record 18 of Set 4 | alofi
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | aklavik
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | el faiyum
# City not found. Skipping...
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | san jeronimo
# Processing Record 25 of Set 4 | drovyanaya
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | klaksvik
# Processing Record 28 of Set 4 | kautokeino
# Processing Record 29 of Set 4 | scottsbluff
# Processing Record 30 of Set 4 | enniscorthy
# Processing Record 31 of Set 4 | la palma
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | paita
# Processing Record 35 of Set 4 | saint george
# Processing Record 36 of Set 4 | mawlaik
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | cape town
# Processing Record 39 of Set 4 | santa rosa
# Processing Record 40 of Set 4 | kota tinggi
# Processing Record 41 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 4 | san rafael
# Processing Record 43 of Set 4 | pochutla
# Processing Record 44 of Set 4 | tilichiki
# Processing Record 45 of Set 4 | kedrovyy
# Processing Record 46 of Set 4 | matay
# Processing Record 47 of Set 4 | zatoka
# Processing Record 48 of Set 4 | ternate
# Processing Record 49 of Set 4 | shenjiamen
# Processing Record 50 of Set 4 | severnoye
# Processing Record 1 of Set 5 | alice springs
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | pangkalanbuun
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | ahipara
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | hay river
# Processing Record 8 of Set 5 | teya
# Processing Record 9 of Set 5 | pedasi
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | smithers
# Processing Record 12 of Set 5 | erzin
# Processing Record 13 of Set 5 | vieste
# Processing Record 14 of Set 5 | shagonar
# Processing Record 15 of Set 5 | battle creek
# Processing Record 16 of Set 5 | nikolskoye
# Processing Record 17 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 5 | bon accord
# Processing Record 19 of Set 5 | barbosa ferraz
# Processing Record 20 of Set 5 | palana
# Processing Record 21 of Set 5 | bilibino
# Processing Record 22 of Set 5 | arawa
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | pouebo
# Processing Record 25 of Set 5 | belmonte
# Processing Record 26 of Set 5 | maun
# Processing Record 27 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 5 | nouadhibou
# Processing Record 29 of Set 5 | beisfjord
# Processing Record 30 of Set 5 | bayji
# Processing Record 31 of Set 5 | lucapa
# Processing Record 32 of Set 5 | upernavik
# Processing Record 33 of Set 5 | baoning
# Processing Record 34 of Set 5 | camacha
# Processing Record 35 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | rio grande
# Processing Record 38 of Set 5 | kangaatsiaq
# Processing Record 39 of Set 5 | bambous virieux
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | shimoda
# Processing Record 43 of Set 5 | sayalgudi
# City not found. Skipping...
# Processing Record 44 of Set 5 | chebenki
# Processing Record 45 of Set 5 | jurilovca
# Processing Record 46 of Set 5 | samana
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | severo-kurilsk
# Processing Record 49 of Set 5 | keflavik
# Processing Record 50 of Set 5 | richards bay
# Processing Record 1 of Set 6 | carberry
# Processing Record 2 of Set 6 | koboldo
# City not found. Skipping...
# Processing Record 3 of Set 6 | bay roberts
# Processing Record 4 of Set 6 | jumla
# Processing Record 5 of Set 6 | lujan
# Processing Record 6 of Set 6 | kaeo
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | tahta
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | bac lieu
# Processing Record 11 of Set 6 | zhuanghe
# Processing Record 12 of Set 6 | villa corzo
# Processing Record 13 of Set 6 | san vicente
# Processing Record 14 of Set 6 | kati
# Processing Record 15 of Set 6 | sept-iles
# Processing Record 16 of Set 6 | wanaka
# Processing Record 17 of Set 6 | tongchuan
# Processing Record 18 of Set 6 | sao joao da barra
# Processing Record 19 of Set 6 | faanui
# Processing Record 20 of Set 6 | botad
# Processing Record 21 of Set 6 | nioro
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | cacador
# Processing Record 24 of Set 6 | ilhabela
# Processing Record 25 of Set 6 | calais
# Processing Record 26 of Set 6 | verkhniy landekh
# Processing Record 27 of Set 6 | yumen
# Processing Record 28 of Set 6 | port macquarie
# Processing Record 29 of Set 6 | sal rei
# Processing Record 30 of Set 6 | nanortalik
# Processing Record 31 of Set 6 | mingguang
# Processing Record 32 of Set 6 | arraial do cabo
# Processing Record 33 of Set 6 | hirado
# Processing Record 34 of Set 6 | tikhvin
# Processing Record 35 of Set 6 | ekhabi
# Processing Record 36 of Set 6 | leshukonskoye
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | flin flon
# Processing Record 39 of Set 6 | vestmannaeyjar
# Processing Record 40 of Set 6 | san quintin
# Processing Record 41 of Set 6 | santa maria
# Processing Record 42 of Set 6 | guerrero negro
# Processing Record 43 of Set 6 | nouakchott
# Processing Record 44 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | larsnes
# Processing Record 46 of Set 6 | jardim de piranhas
# Processing Record 47 of Set 6 | collie
# Processing Record 48 of Set 6 | general pico
# Processing Record 49 of Set 6 | bonthe
# Processing Record 50 of Set 6 | laguna
# Processing Record 1 of Set 7 | kidal
# Processing Record 2 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 7 | saint-francois
# Processing Record 4 of Set 7 | marawi
# Processing Record 5 of Set 7 | goundam
# Processing Record 6 of Set 7 | bardiyah
# Processing Record 7 of Set 7 | trat
# Processing Record 8 of Set 7 | sungaipenuh
# Processing Record 9 of Set 7 | holsted
# Processing Record 10 of Set 7 | salalah
# Processing Record 11 of Set 7 | kakucs
# Processing Record 12 of Set 7 | balabac
# Processing Record 13 of Set 7 | san patricio
# Processing Record 14 of Set 7 | sinnamary
# Processing Record 15 of Set 7 | caravelas
# Processing Record 16 of Set 7 | dumas
# Processing Record 17 of Set 7 | peleduy
# Processing Record 18 of Set 7 | xiuyan
# Processing Record 19 of Set 7 | katangli
# Processing Record 20 of Set 7 | luchegorsk
# Processing Record 21 of Set 7 | george
# Processing Record 22 of Set 7 | kawalu
# Processing Record 23 of Set 7 | chapais
# Processing Record 24 of Set 7 | alakurtti
# Processing Record 25 of Set 7 | buchanan
# Processing Record 26 of Set 7 | malinovoye ozero
# Processing Record 27 of Set 7 | berlevag
# Processing Record 28 of Set 7 | ust-nera
# Processing Record 29 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 30 of Set 7 | dwarka
# Processing Record 31 of Set 7 | shestakovo
# Processing Record 32 of Set 7 | millville
# Processing Record 33 of Set 7 | kalemie
# Processing Record 34 of Set 7 | victor harbor
# Processing Record 35 of Set 7 | port hedland
# Processing Record 36 of Set 7 | san jose
# Processing Record 37 of Set 7 | mandali
# Processing Record 38 of Set 7 | yuanping
# Processing Record 39 of Set 7 | saint-philippe
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | prince rupert
# Processing Record 42 of Set 7 | yazd
# Processing Record 43 of Set 7 | hamilton
# Processing Record 44 of Set 7 | athabasca
# Processing Record 45 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 46 of Set 7 | longyearbyen
# Processing Record 47 of Set 7 | tingo maria
# Processing Record 48 of Set 7 | amuntai
# Processing Record 49 of Set 7 | vicosa
# Processing Record 50 of Set 7 | kassala
# Processing Record 1 of Set 8 | alexandria
# Processing Record 2 of Set 8 | petatlan
# Processing Record 3 of Set 8 | puerto leguizamo
# Processing Record 4 of Set 8 | ocho rios
# Processing Record 5 of Set 8 | codrington
# Processing Record 6 of Set 8 | linqiong
# Processing Record 7 of Set 8 | moranbah
# Processing Record 8 of Set 8 | putina
# Processing Record 9 of Set 8 | rastolita
# Processing Record 10 of Set 8 | ukiah
# Processing Record 11 of Set 8 | sao jose da coroa grande
# Processing Record 12 of Set 8 | howard springs
# Processing Record 13 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 14 of Set 8 | burica
# City not found. Skipping...
# Processing Record 15 of Set 8 | dalaba
# Processing Record 16 of Set 8 | kuching
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | gamba
# Processing Record 19 of Set 8 | champerico
# Processing Record 20 of Set 8 | gainesville
# Processing Record 21 of Set 8 | ellensburg
# Processing Record 22 of Set 8 | grindavik
# Processing Record 23 of Set 8 | coquimbo
# Processing Record 24 of Set 8 | sorong
# Processing Record 25 of Set 8 | dodge city
# Processing Record 26 of Set 8 | visby
# Processing Record 27 of Set 8 | puri
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | saldanha
# Processing Record 30 of Set 8 | namatanai
# Processing Record 31 of Set 8 | ola
# Processing Record 32 of Set 8 | zhetybay
# City not found. Skipping...
# Processing Record 33 of Set 8 | faya
# Processing Record 34 of Set 8 | montes altos
# Processing Record 35 of Set 8 | svetlogorsk
# Processing Record 36 of Set 8 | lafiagi
# Processing Record 37 of Set 8 | moate
# Processing Record 38 of Set 8 | barra do garcas
# Processing Record 39 of Set 8 | balkhash
# Processing Record 40 of Set 8 | puerto del rosario
# Processing Record 41 of Set 8 | filadelfia
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | polyarnyy
# Processing Record 44 of Set 8 | namibe
# Processing Record 45 of Set 8 | swan river
# Processing Record 46 of Set 8 | halifax
# Processing Record 47 of Set 8 | buala
# Processing Record 48 of Set 8 | vaasa
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | hovd
# Processing Record 1 of Set 9 | samarai
# Processing Record 2 of Set 9 | cairns
# Processing Record 3 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 9 | cheshunt
# Processing Record 5 of Set 9 | hirara
# Processing Record 6 of Set 9 | les herbiers
# Processing Record 7 of Set 9 | ndioum
# Processing Record 8 of Set 9 | sampit
# Processing Record 9 of Set 9 | porto novo
# Processing Record 10 of Set 9 | vao
# Processing Record 11 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 9 | mineral wells
# Processing Record 13 of Set 9 | praia
# Processing Record 14 of Set 9 | kayerkan
# Processing Record 15 of Set 9 | maneadero
# Processing Record 16 of Set 9 | provideniya
# Processing Record 17 of Set 9 | jaciara
# Processing Record 18 of Set 9 | joshimath
# Processing Record 19 of Set 9 | lichinga
# Processing Record 20 of Set 9 | carangola
# Processing Record 21 of Set 9 | paungde
# Processing Record 22 of Set 9 | mayya
# Processing Record 23 of Set 9 | wewak
# Processing Record 24 of Set 9 | karera
# Processing Record 25 of Set 9 | sitka
# Processing Record 26 of Set 9 | kapit
# Processing Record 27 of Set 9 | la ronge
# Processing Record 28 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 9 | sur
# Processing Record 30 of Set 9 | krasnoarmeyskoye
# Processing Record 31 of Set 9 | dengzhou
# Processing Record 32 of Set 9 | nyurba
# Processing Record 33 of Set 9 | demikhovo
# Processing Record 34 of Set 9 | fuerte olimpo
# Processing Record 35 of Set 9 | atlantic city
# Processing Record 36 of Set 9 | sao filipe
# Processing Record 37 of Set 9 | san carlos de bariloche
# Processing Record 38 of Set 9 | binabalian
# Processing Record 39 of Set 9 | hambantota
# Processing Record 40 of Set 9 | osa
# Processing Record 41 of Set 9 | coihaique
# Processing Record 42 of Set 9 | tuatapere
# Processing Record 43 of Set 9 | dinard
# Processing Record 44 of Set 9 | komsomolskiy
# Processing Record 45 of Set 9 | nishihara
# Processing Record 46 of Set 9 | kauhajoki
# Processing Record 47 of Set 9 | khasan
# Processing Record 48 of Set 9 | muros
# Processing Record 49 of Set 9 | taylor
# Processing Record 50 of Set 9 | roebourne
# Processing Record 1 of Set 10 | mahebourg
# Processing Record 2 of Set 10 | ginir
# Processing Record 3 of Set 10 | abaza
# Processing Record 4 of Set 10 | xai-xai
# Processing Record 5 of Set 10 | bengkulu
# Processing Record 6 of Set 10 | williamsburg
# Processing Record 7 of Set 10 | souillac
# Processing Record 8 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 9 of Set 10 | weligama
# Processing Record 10 of Set 10 | genhe
# Processing Record 11 of Set 10 | andros town
# Processing Record 12 of Set 10 | los llanos de aridane
# Processing Record 13 of Set 10 | houma
# Processing Record 14 of Set 10 | watsonville
# Processing Record 15 of Set 10 | tukrah
# Processing Record 16 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 10 | heihe
# Processing Record 18 of Set 10 | chicama
# Processing Record 19 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 10 | banjarmasin
# Processing Record 21 of Set 10 | erenhot
# Processing Record 22 of Set 10 | cocorit
# Processing Record 23 of Set 10 | tome
# Processing Record 24 of Set 10 | naze
# Processing Record 25 of Set 10 | suez
# Processing Record 26 of Set 10 | mukhtolovo
# Processing Record 27 of Set 10 | nizwa
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | araceli
# Processing Record 30 of Set 10 | mogadishu
# Processing Record 31 of Set 10 | lukhovka
# Processing Record 32 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 33 of Set 10 | payson
# Processing Record 34 of Set 10 | yenagoa
# Processing Record 35 of Set 10 | glenwood springs
# Processing Record 36 of Set 10 | siderno
# Processing Record 37 of Set 10 | ostersund
# Processing Record 38 of Set 10 | teshie
# Processing Record 39 of Set 10 | burgeo
# Processing Record 40 of Set 10 | henties bay
# Processing Record 41 of Set 10 | bukachacha
# Processing Record 42 of Set 10 | sharjah
# Processing Record 43 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 10 | quatre cocos
# Processing Record 46 of Set 10 | oistins
# Processing Record 47 of Set 10 | the valley
# Processing Record 48 of Set 10 | lebu
# Processing Record 49 of Set 10 | ghansor
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | makat
# Processing Record 2 of Set 11 | zonguldak
# Processing Record 3 of Set 11 | dudinka
# Processing Record 4 of Set 11 | talcahuano
# Processing Record 5 of Set 11 | atbasar
# Processing Record 6 of Set 11 | kidero
# Processing Record 7 of Set 11 | jalu
# Processing Record 8 of Set 11 | mitsamiouli
# Processing Record 9 of Set 11 | calvinia
# Processing Record 10 of Set 11 | honiara
# Processing Record 11 of Set 11 | constitucion
# Processing Record 12 of Set 11 | kibala
# Processing Record 13 of Set 11 | mokhsogollokh
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | guaymas
# Processing Record 16 of Set 11 | egvekinot
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | katobu
# Processing Record 19 of Set 11 | kinna
# Processing Record 20 of Set 11 | ust-tsilma
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | parnu
# Processing Record 23 of Set 11 | bambanglipuro
# Processing Record 24 of Set 11 | lena
# Processing Record 25 of Set 11 | srandakan
# Processing Record 26 of Set 11 | bairiki
# Processing Record 27 of Set 11 | trujillo
# Processing Record 28 of Set 11 | tezu
# Processing Record 29 of Set 11 | narsaq
# Processing Record 30 of Set 11 | estelle
# Processing Record 31 of Set 11 | montmagny
# Processing Record 32 of Set 11 | sarahan
# Processing Record 33 of Set 11 | kaoma
# Processing Record 34 of Set 11 | ambon
# Processing Record 35 of Set 11 | vardo
# Processing Record 36 of Set 11 | klyuchevskiy
# Processing Record 37 of Set 11 | coroata
# Processing Record 38 of Set 11 | port shepstone
# Processing Record 39 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 11 | ler
# Processing Record 41 of Set 11 | at-bashi
# Processing Record 42 of Set 11 | fergus falls
# Processing Record 43 of Set 11 | anito
# Processing Record 44 of Set 11 | mwinilunga
# Processing Record 45 of Set 11 | muchkapskiy
# Processing Record 46 of Set 11 | kumluca
# Processing Record 47 of Set 11 | maumere
# Processing Record 48 of Set 11 | mareeba
# Processing Record 49 of Set 11 | biloela
# Processing Record 50 of Set 11 | ureki
# Processing Record 1 of Set 12 | ohara
# Processing Record 2 of Set 12 | nampula
# Processing Record 3 of Set 12 | alyangula
# Processing Record 4 of Set 12 | starogard gdanski
# Processing Record 5 of Set 12 | yar-sale
# Processing Record 6 of Set 12 | inyonga
# Processing Record 7 of Set 12 | chopinzinho
# Processing Record 8 of Set 12 | kemijarvi
# Processing Record 9 of Set 12 | tabuan
# Processing Record 10 of Set 12 | polson
# Processing Record 11 of Set 12 | surgut
# Processing Record 12 of Set 12 | xichang
# Processing Record 13 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 12 | luau
# Processing Record 15 of Set 12 | sarkand
# Processing Record 16 of Set 12 | soe
# Processing Record 17 of Set 12 | olenino
# Processing Record 18 of Set 12 | kandrian
# Processing Record 19 of Set 12 | carlsbad
# Processing Record 20 of Set 12 | tra vinh
# Processing Record 21 of Set 12 | bauchi
# Processing Record 22 of Set 12 | ossora
# Processing Record 23 of Set 12 | tranas
# Processing Record 24 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 12 | meiktila
# Processing Record 26 of Set 12 | poum
# Processing Record 27 of Set 12 | mamallapuram
# Processing Record 28 of Set 12 | minot
# Processing Record 29 of Set 12 | udachnyy
# Processing Record 30 of Set 12 | launceston
# Processing Record 31 of Set 12 | aswan
# Processing Record 32 of Set 12 | dawson creek
# Processing Record 33 of Set 12 | madoc
# Processing Record 34 of Set 12 | pierre
# Processing Record 35 of Set 12 | lensk
# Processing Record 36 of Set 12 | cristalina
# Processing Record 37 of Set 12 | camabatela
# Processing Record 38 of Set 12 | zhigansk
# Processing Record 39 of Set 12 | hailey
# Processing Record 40 of Set 12 | huangnihe
# Processing Record 41 of Set 12 | senanga
# Processing Record 42 of Set 12 | acapulco
# Processing Record 43 of Set 12 | palapye
# Processing Record 44 of Set 12 | villarrica
# Processing Record 45 of Set 12 | joao pinheiro
# Processing Record 46 of Set 12 | praia da vitoria
# Processing Record 47 of Set 12 | atar
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | shellbrook
# Processing Record 50 of Set 12 | usman
# Processing Record 1 of Set 13 | mirpur sakro
# Processing Record 2 of Set 13 | ambunti
# Processing Record 3 of Set 13 | thinadhoo
# Processing Record 4 of Set 13 | saint-joseph
# Processing Record 5 of Set 13 | iturama
# Processing Record 6 of Set 13 | luderitz
# Processing Record 7 of Set 13 | grand gaube
# Processing Record 8 of Set 13 | maralal
# Processing Record 9 of Set 13 | ligayan
# Processing Record 10 of Set 13 | linxia
# Processing Record 11 of Set 13 | sakaiminato
# Processing Record 12 of Set 13 | ust-ishim
# Processing Record 13 of Set 13 | itarema
# Processing Record 14 of Set 13 | quelimane
# Processing Record 15 of Set 13 | sestri levante
# Processing Record 16 of Set 13 | gambela
# Processing Record 17 of Set 13 | amapa
# Processing Record 18 of Set 13 | mishan
# Processing Record 19 of Set 13 | trinidad
# Processing Record 20 of Set 13 | gazanjyk
# Processing Record 21 of Set 13 | belyy yar
# Processing Record 22 of Set 13 | palmer
# Processing Record 23 of Set 13 | san andres
# Processing Record 24 of Set 13 | carutapera
# Processing Record 25 of Set 13 | saint-ambroise
# Processing Record 26 of Set 13 | ilebo
# Processing Record 27 of Set 13 | urengoy
# Processing Record 28 of Set 13 | grand island
# Processing Record 29 of Set 13 | vigo
# Processing Record 30 of Set 13 | kortkeros
# Processing Record 31 of Set 13 | bunia
# Processing Record 32 of Set 13 | atasu
# Processing Record 33 of Set 13 | traverse city
# Processing Record 34 of Set 13 | ilulissat
# Processing Record 35 of Set 13 | necochea
# Processing Record 36 of Set 13 | newport
# Processing Record 37 of Set 13 | touros
# Processing Record 38 of Set 13 | coos bay
# Processing Record 39 of Set 13 | bako
# Processing Record 40 of Set 13 | waingapu
# Processing Record 41 of Set 13 | plettenberg bay
# Processing Record 42 of Set 13 | neyshabur
# Processing Record 43 of Set 13 | oranjemund
# Processing Record 44 of Set 13 | arman
# Processing Record 45 of Set 13 | solikamsk
# Processing Record 46 of Set 13 | bismarck
# Processing Record 47 of Set 13 | honningsvag
# Processing Record 48 of Set 13 | hofn
# Processing Record 49 of Set 13 | taubate
# Processing Record 50 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 1 of Set 14 | guiratinga
# Processing Record 2 of Set 14 | sharon
# Processing Record 3 of Set 14 | charters towers
# Processing Record 4 of Set 14 | amravati
# Processing Record 5 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | jalingo
# Processing Record 7 of Set 14 | oussouye
# Processing Record 8 of Set 14 | foki
# Processing Record 9 of Set 14 | san luis
# Processing Record 10 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 14 | itaituba
# Processing Record 12 of Set 14 | salinopolis
# Processing Record 13 of Set 14 | poso
# Processing Record 14 of Set 14 | murmashi
# Processing Record 15 of Set 14 | marovoay
# Processing Record 16 of Set 14 | aginskoye
# Processing Record 17 of Set 14 | broken hill
# Processing Record 18 of Set 14 | sao felix do xingu
# Processing Record 19 of Set 14 | lysyye gory
# Processing Record 20 of Set 14 | rocha
# Processing Record 21 of Set 14 | kashi
# Processing Record 22 of Set 14 | praxedis guerrero
# Processing Record 23 of Set 14 | shibetsu
# Processing Record 24 of Set 14 | elizabeth city
# Processing Record 25 of Set 14 | matara
# Processing Record 26 of Set 14 | valle de allende
# Processing Record 27 of Set 14 | camargo
# Processing Record 28 of Set 14 | limoux
# Processing Record 29 of Set 14 | waterloo
# Processing Record 30 of Set 14 | victoria
# Processing Record 31 of Set 14 | pemba
# Processing Record 32 of Set 14 | yanam
# Processing Record 33 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 34 of Set 14 | chiang khong
# Processing Record 35 of Set 14 | abu dhabi
# Processing Record 36 of Set 14 | chilca
# Processing Record 37 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 14 | hurghada
# Processing Record 39 of Set 14 | yaan
# Processing Record 40 of Set 14 | maniitsoq
# Processing Record 41 of Set 14 | boyolangu
# Processing Record 42 of Set 14 | dinar
# Processing Record 43 of Set 14 | candolim
# Processing Record 44 of Set 14 | george town
# Processing Record 45 of Set 14 | key largo
# Processing Record 46 of Set 14 | amazar
# Processing Record 47 of Set 14 | sadovoye
# Processing Record 48 of Set 14 | tallahassee
# Processing Record 49 of Set 14 | manicore
# Processing Record 50 of Set 14 | ixtapa
# Processing Record 1 of Set 15 | kingman
# Processing Record 2 of Set 15 | morant bay
# Processing Record 3 of Set 15 | tecoanapa
# Processing Record 4 of Set 15 | palauig
# Processing Record 5 of Set 15 | bowen
# Processing Record 6 of Set 15 | karia
# Processing Record 7 of Set 15 | emerald
# Processing Record 8 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 9 of Set 15 | shahdadpur
# Processing Record 10 of Set 15 | northam
# Processing Record 11 of Set 15 | havelock
# Processing Record 12 of Set 15 | iki-burul
# Processing Record 13 of Set 15 | mocajuba
# Processing Record 14 of Set 15 | caborca
# Processing Record 15 of Set 15 | ketchikan
# Processing Record 16 of Set 15 | ozu
# Processing Record 17 of Set 15 | adrar
# Processing Record 18 of Set 15 | rafraf
# Processing Record 19 of Set 15 | johnson city
# Processing Record 20 of Set 15 | dubovka
# Processing Record 21 of Set 15 | wadi maliz
# Processing Record 22 of Set 15 | ishigaki
# Processing Record 23 of Set 15 | fortuna
# Processing Record 24 of Set 15 | sibolga
# Processing Record 25 of Set 15 | te anau
# Processing Record 26 of Set 15 | severnyy
# Processing Record 27 of Set 15 | talnakh
# Processing Record 28 of Set 15 | puerto baquerizo moreno
# Processing Record 29 of Set 15 | phan thiet
# Processing Record 30 of Set 15 | wallacetown
# Processing Record 31 of Set 15 | izhma
# Processing Record 32 of Set 15 | cap malheureux
# Processing Record 33 of Set 15 | ponta delgada
# Processing Record 34 of Set 15 | danane
# Processing Record 35 of Set 15 | voh
# Processing Record 36 of Set 15 | sukhumi
# Processing Record 37 of Set 15 | mangaratiba
# Processing Record 38 of Set 15 | schaffhausen
# Processing Record 39 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 15 | micheweni
# Processing Record 41 of Set 15 | nakhon thai
# Processing Record 42 of Set 15 | sainte-rose
# Processing Record 43 of Set 15 | umm kaddadah
# Processing Record 44 of Set 15 | fukue
# Processing Record 45 of Set 15 | maldonado
# Processing Record 46 of Set 15 | santa fe
# Processing Record 47 of Set 15 | young
# Processing Record 48 of Set 15 | mangalia
# Processing Record 49 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 15 | jackson
# Processing Record 1 of Set 16 | vangaindrano
# Processing Record 2 of Set 16 | aurora
# Processing Record 3 of Set 16 | sangar
# Processing Record 4 of Set 16 | chernihiv
# Processing Record 5 of Set 16 | xingcheng
# Processing Record 6 of Set 16 | sao gabriel da cachoeira
# Processing Record 7 of Set 16 | khormuj
# City not found. Skipping...
# Processing Record 8 of Set 16 | beni
# Processing Record 9 of Set 16 | san rafael del sur
# Processing Record 10 of Set 16 | ruston
# Processing Record 11 of Set 16 | willowmore
# Processing Record 12 of Set 16 | yermish
# Processing Record 13 of Set 16 | waipawa
# Processing Record 14 of Set 16 | brownsville
# Processing Record 15 of Set 16 | solano
# Processing Record 16 of Set 16 | kieta
# Processing Record 17 of Set 16 | gornopravdinsk
# Processing Record 18 of Set 16 | talaya
# Processing Record 19 of Set 16 | lisburn
# Processing Record 20 of Set 16 | agirish
# Processing Record 21 of Set 16 | kiama
# Processing Record 22 of Set 16 | yairipok
# Processing Record 23 of Set 16 | davila
# Processing Record 24 of Set 16 | galt
# Processing Record 25 of Set 16 | khandagayty
# Processing Record 26 of Set 16 | itoman
# Processing Record 27 of Set 16 | jacqueville
# Processing Record 28 of Set 16 | asyut
# Processing Record 29 of Set 16 | usinsk
# Processing Record 30 of Set 16 | bereda
# Processing Record 31 of Set 16 | westport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 781

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Takoradi   4.8845   -1.7554     72.46        87           1
# 1    Yellowknife  62.4560 -114.3525     59.52        94         100
# 2          Duvan  55.6950   57.9024     59.31        83          17
# 3         Avarua -21.2078 -159.7750     77.05        69          75
# 4       Cernesti  47.5167   23.7500     70.50        57          86
# 5         Atuona  -9.8000 -139.0333     76.80        80          43
# 6           Aksu  41.1231   80.2644     68.56        62          20
# 7  Saint Anthony  45.0205  -93.2180     77.05        86         100
# 8        Margate  51.3813    1.3862     62.31        75          42
# 9           Gizo  -8.1030  156.8419     83.34        73          94
#
#    Wind Speed Weather Decription Country                 Date
# 0        6.96          clear sky      GH  2022-08-06 22:33:56
# 1        9.22         light rain      CA  2022-08-06 22:33:56
# 2        2.86         few clouds      RU  2022-08-06 22:33:57
# 3       16.11      broken clouds      CK  2022-08-06 22:33:57
# 4        2.06    overcast clouds      RO  2022-08-06 22:33:57
# 5       16.31         light rain      PF  2022-08-06 22:33:58
# 6        3.53         few clouds      CN  2022-08-06 22:33:58
# 7       11.50    overcast clouds      US  2022-08-06 22:33:58
# 8        1.99   scattered clouds      GB  2022-08-06 22:33:59
# 9        9.82         light rain      SB  2022-08-06 22:33:59

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Decription"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Takoradi      GH   4.8845   -1.7554     72.46        87           1
# 1    Yellowknife      CA  62.4560 -114.3525     59.52        94         100
# 2          Duvan      RU  55.6950   57.9024     59.31        83          17
# 3         Avarua      CK -21.2078 -159.7750     77.05        69          75
# 4       Cernesti      RO  47.5167   23.7500     70.50        57          86
# 5         Atuona      PF  -9.8000 -139.0333     76.80        80          43
# 6           Aksu      CN  41.1231   80.2644     68.56        62          20
# 7  Saint Anthony      US  45.0205  -93.2180     77.05        86         100
# 8        Margate      GB  51.3813    1.3862     62.31        75          42
# 9           Gizo      SB  -8.1030  156.8419     83.34        73          94
#
#    Wind Speed Weather Decription
# 0        6.96          clear sky
# 1        9.22         light rain
# 2        2.86         few clouds
# 3       16.11      broken clouds
# 4        2.06    overcast clouds
# 5       16.31         light rain
# 6        3.53         few clouds
# 7       11.50    overcast clouds
# 8        1.99   scattered clouds
# 9        9.82         light rain

# %%
city_data_df.rename(columns = {'Weather Decription':'Current Description'}, inplace = True)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Takoradi      GH   4.8845   -1.7554     72.46        87           1
# 1    Yellowknife      CA  62.4560 -114.3525     59.52        94         100
# 2          Duvan      RU  55.6950   57.9024     59.31        83          17
# 3         Avarua      CK -21.2078 -159.7750     77.05        69          75
# 4       Cernesti      RO  47.5167   23.7500     70.50        57          86
# 5         Atuona      PF  -9.8000 -139.0333     76.80        80          43
# 6           Aksu      CN  41.1231   80.2644     68.56        62          20
# 7  Saint Anthony      US  45.0205  -93.2180     77.05        86         100
# 8        Margate      GB  51.3813    1.3862     62.31        75          42
# 9           Gizo      SB  -8.1030  156.8419     83.34        73          94
#
#    Wind Speed Current Description
# 0        6.96           clear sky
# 1        9.22          light rain
# 2        2.86          few clouds
# 3       16.11       broken clouds
# 4        2.06     overcast clouds
# 5       16.31          light rain
# 6        3.53          few clouds
# 7       11.50     overcast clouds
# 8        1.99    scattered clouds
# 9        9.82          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
